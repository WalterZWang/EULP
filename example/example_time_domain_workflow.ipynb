# %% [markdown]
# ### Time-domain analysis workflow
#
# This workbook contains a workflow to:
# 1. Cluster the load profiles with time series load shape
# 2. Calculate the distribution of key statistcis for each cluster

# %% [markdown]
# #### Part 0. Set the paths and import the modules needed for this workflow, descriptions of each module can be find in the README.md

# %%
# Run this cell only at the first kernel starts
# %cd ..

from EULP.LP_timeDomain import time_domain_analysis, select_cluster_number
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib import style
import os
# Out:
# C:\Users\walter\Desktop\git\EULP

# %% [markdown]
# #### Part 1. Explore the optimal number of clusters for time domain analysis
#
# This clustering is on time series load profile. Each day of each building is a sample. We first resample the load to hourly interval, and then cluster on this 24-dimension vector.

# %%
path = "example\data"
result_path = "result\LBNL_Case_1"

# %%
select_cluster_number(path,[2,8],result_path)
# Out:
# Time consumed: 0.0011799087127049763 h

# %% [markdown]
# Then check the figures in ``result_path`` to determine the optimal number of clusters.
# Let's see we selected 4 as the optimal number of clusters.
#
# #### Part 2. Cluster with the optimal number of clusters, calculate the key statics and cluster center for each cluster

# %%
number_of_clusters = 4
time_domain_analysis(path, number_of_clusters, result_path)
# Out:
# Time consumed: 0.0005944522221883138 h
# cluster 0: 126
# cluster 1: 237
# cluster 2: 255
# cluster 3: 114

# %% [markdown]
# Please share the csv files in the ``result_path`` with us
